# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
#
# Ans. The source code is translated into machine code once, which is specific to the target. Whereas in interpreted languages source code is interpreted and translated each time the programme runs.
#
#
# 2. What is exception handling in Python?
#
# Ans. It is a technique to manage errors during executiona and prevent crashes.
#
#
# 3. What is the purpose of the finally block in exception handling?
#
# Ans. The finally block will always be executed, no matter if the try block raises an error or not.
#
#
# 4. What is logging in Python?
#
# Ans. Logging in Python is a way to record information about your Python scripts and keep track of events generated by the scripts as they take place.
#
#
# 5. What is the significance of the __del__ method in Python?
#
# Ans. it is a destructor method, Performs cleanup, resource release, or other “finalization” actions.
#
#
# 6. What is the difference between import and from ... import in Python?
#
# Ans.The difference between 'import' and 'from import' is that using 'import' you import the whole module. 'from import' you import a part of it.
#
#
# 7. How can you handle multiple exceptions in Python?
#
# Ans. Python allows you to catch multiple exceptions in a single try-except block by using a tuple of exception types. For example: except (TypeError, ValueError)
#
#
# 8. What is the purpose of the with statement when handling files in Python?
#
# Ans.In Python, with statement is used in exception handling to make the code cleaner and much more readable. It simplifies the management of common resources like file streams
#
#
# 9. What is the difference between multithreading and multiprocessing?
#
# Ans. Multiprocessing uses multiple CPUs to run many processes at a time while multithreading creates multiple threads within a single process to get faster and more efficient task execution.
#
#
# 10. What are the advantages of using logging in a program?
#
# Ans. Logging is essential to understand the behaviour of the application and to debug unexpected issues or for simply tracking events.
#
#
# 11. What is memory management in Python?
#
# Ans.Memory management in Python is the process of allocating and freeing memory for a program to run efficiently
#
#
# 12. What are the basic steps involved in exception handling in Python?
#
# Ans.In Python, the basic steps for exception handling involve using a "try...except" block, where you place the code that might raise an error within the "try" block, and then use the "except" block to catch and handle any exceptions that occur within the "try" block
#
#
# 13. Why is memory management important in Python?
#
# Ans.Memory management in Python is important because it ensures that programs run efficiently and have enough memory to store their data.
#
#
# 14. What is the role of try and except in exception handling?
#
# Ans.The try block lets you test a block of code for errors. The except block lets you handle the error.
#
#
# 15. How does Python's garbage collection system work?
#
# Ans. The garbage collector in Python locates and releases memory occupied by objects that can no longer be accessed or referenced by the program's code.
#
#
# 16. What is the purpose of the else block in exception handling?
#
# Ans. The else block lets you execute code when there is no error.
#
#
# 17. What are the common logging levels in Python?
#
# Ans.Debug , info, warning, error, critical are some common logging levels in Python.
#
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
#
# Ans.The difference between the os.fork and multiprocessing.Process is portability and library overhead, since os.fork is not supported in windows, and the multiprocessing framework is included to make multiprocessing.Process work.
#
#
# 19. What is the importance of closing a file in Python?
#
# Ans. Because files are limited resources managed by the operating system, making sure files are closed after use will protect against hard-to-debug issues like running out of file handles or experiencing corrupted data.
#
#
# 20. What is the difference between file.read() and file.readline() in Python?
#
# Ans. Read method reads the whole file as a single string while readlines segregates each of the line in the file and you then can later on call them line by line.
#
#
# 21. What is the logging module in Python used for?
#
# Ans.Python logging module allows you to track events that occur while your program is running.
#
#
# 22. What is the os module in Python used for in file handling?
#
# Ans.The OS module in Python provides functions for interacting with the operating system. OS comes under Python’s standard utility modules. This module provides a portable way of using operating system-dependent functionality.
#
#
# 23. What are the challenges associated with memory management in Python?
#
# Ans. The primary challenge with memory management in Python is the potential for memory leaks due to its automatic garbage collection system
#
#
# 24. How do you raise an exception manually in Python?
#
# Ans. By using raise statement you can raise exception manually in Python.
#
#
# 25. Why is it important to use multithreading in certain applications?
#
# Ans.In some applications it is easier to code different remote procedure calls and conversations in separate threads than to manage them from the same thread.

# %%
#1  How can you open a file for writing in Python and write a string to it
f=open("practise.txt","w")
f.write("This is my first file")
f.close()

# %%
# 2 Write a Python program to read the contents of a file and print each line

with open("practise.txt","r") as f:
    print(f.read())
# Out:
# This is my first file

# %%
#3How would you handle a case where the file doesn't exist while trying to open it for reading

try:
    with open("practise1.txt","r") as f:
        print(f.read())
except Exception as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'practise1.txt'

# %%
 #4 Write a Python script that reads from one file and writes its content to another file

f=open("practise.txt","r")
f1=open("practise1.txt","w")
f1.write(f.read())
f.close()
f1.close()

# %%
 #5 How would you catch and handle division by zero error in Python

try:
    a=10/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
#6Write a Python program that logs an error message to a log file when a division by zero exception occurs

import logging
logging.basicConfig(filename="error.log",level=logging.ERROR)
try:
    a=10/0
except ZeroDivisionError as e:
    logging.error(e)
# Out:
# ERROR:root:division by zero

# %%
#7 How do you log information at different levels (INFO, ERROR, WARNING) in python using the logging module

import logging
logging.basicConfig(filename="error.log",level=logging.ERROR)
try:
    a=10/0
except ZeroDivisionError as e:
    logging.error(e)
    logging.info("This is info")
    logging.warning("This is warning")
# Out:
# ERROR:root:division by zero
# WARNING:root:This is warning

# %%
 #8 Write a program to handle a file opening error using exception handling

try:
    with open("practise12.txt","r") as f:
        print(f.read())
except Exception as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'practise12.txt'

# %%
 #9 How can you read a file line by line and store its content in a list in Python

f=open("practise.txt","r")
l=f.readlines()
print(l)
# Out:
# ['This is my first file']

# %%
 #10 How can you append data to an existing file in Python

f=open("practise.txt","a")
f.write("\nThis is more data I am adding")
f.close()

# %%
'''11 Write a Python program that uses a try-except block to handle an error when attempting to access a
dictionary key that doesn't exist'''

try:
    d={"a":1,"b":2}
    print(d["c"])
except KeyError as e:
    print(e)
# Out:
# 'c'

# %%
#12 Write a program that demonstrates using multiple except blocks to handle different types of exceptions

try:
    a=10/0
except ZeroDivisionError as e:
    print(e)
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
#13 How would you check if a file exists before attempting to read it in Python

import os
if os.path.exists("practise.txt"):
    with open("practise.txt","r") as f:
        print(f.read())
else:
    print("File does not exist")
# Out:
# This is my first fileThis is my first file
# This is my first file
# This is more data I am adding

# %%
 #14 Write a program that uses the logging module to log both informational and error messages

import logging
logging.basicConfig(filename="error.log",level=logging.ERROR)
try:
    a=10/0
except ZeroDivisionError as e:
    logging.error(e)
    logging.info("This is info")
# Out:
# ERROR:root:division by zero

# %%
#15 Write a Python program that prints the content of a file and handles the case when the file is empty

try:
    with open("practise.txt","r") as f:
        print(f.read())
except Exception as e:
    print(e)
# Out:
# This is my first fileThis is my first file
# This is my first file
# This is more data I am adding

# %%
 #16 Demonstrate how to use memory profiling to check the memory usage of a small program
# !pip install memory_profiler

import memory_profiler



@memory_profiler.profile

def factorial(n):

    if n <= 1:

        return 1

    else:

        return n * factorial(n-1)


memusg=memory_profiler.memory_usage((factorial,(),{'n':5}))
print(memusg)
# Out:
# ...
# ERROR: Could not find file <ipython-input-44-b8374c6ba55f>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# ERROR: Could not find file <ipython-input-44-b8374c6ba55f>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# ERROR: Could not find file <ipython-input-44-b8374c6ba55f>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# ERROR: Could not find file <ipython-input-44-b8374c6ba55f>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# ERROR: Could not find file <ipython-input-44-b8374c6ba55f>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# ERROR: Could not find file <ipython-input-44-b8374c6ba55f>
# ...

# %%
 #17 Write a Python program to create and write a list of numbers to a file, one number per line

f=open("practise.txt","w")
l=[1,2,3,4,5]
for i in l:
    f.write(str(i)+"\n")
f.close()

# %%
#18 How would you implement a basic logging setup that logs to a file with rotation after 1MB


import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

handler = RotatingFileHandler('app.log', maxBytes=1000000, backupCount=5)
logger.addHandler(handler)

logger.info('This is an info message.')
logger.warning('This is a warning message.')
logger.error('This is an error message.')
logger.critical('This is a critical message.')
# Out:
# INFO:__main__:This is an info message.
# WARNING:__main__:This is a warning message.
# ERROR:__main__:This is an error message.
# CRITICAL:__main__:This is a critical message.

# %%
#19 Write a program that handles both IndexError and KeyError using a try-except block

try:
    l=[1,2,3,4]
    print(l[5])
except IndexError as e:
    print(e)
except KeyError as e:
    print(e)
# Out:
# list index out of range

# %%
#20 How would you open a file and read its contents using a context manager in Python

with open("practise.txt","r") as f:
    print(f.read())
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#21 Write a Python program that reads a file and prints the number of occurrences of a specific word

f=open("practise1.txt","r")
l=f.read().split()
count=0
for i in l:
    if i=="This":
        count+=1
print(count)
# Out:
# 1

# %%
#22 How can you check if a file is empty before attempting to read its contents

import os
if os.path.getsize("practise.txt")==0:
    print("File is empty")
else:
    print("File is not empty")
# Out:
# File is not empty

# %%
#23 Write a Python program that writes to a log file when an error occurs during file handling.

import logging
logging.basicConfig(filename="error.log",level=logging.ERROR)
try:
    with open("practise.txt","r") as f:
        print(f.read())
except Exception as e:
    logging.error(e)
# Out:
# 1
# 2
# 3
# 4
# 5
